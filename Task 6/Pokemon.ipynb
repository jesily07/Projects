# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
import scipy

# %%
data_pokemon = pd.read_csv("pokemon.csv")

# %%
pd.DataFrame(data_pokemon)
# Out:
#      SI no                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0        1              Bulbasaur    Grass  Poison    318  45      49
# 1        2                Ivysaur    Grass  Poison    405  60      62
# 2        3               Venusaur    Grass  Poison    525  80      82
# 3        3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4        4             Charmander     Fire     NaN    309  39      52
# ..     ...                    ...      ...     ...    ...  ..     ...
# 795    719                Diancie     Rock   Fairy    600  50     100
# 796    719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797    720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798    720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799    721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# ...

# %%
data_pokeman.describe()
# Out:
#             SI no      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data_pokeman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SI no       800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data_pokeman.shape
# Out:
# (800, 13)

# %%
data_pokeman.isnull().sum()
# Out:
# SI no           0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
data_pokeman.drop(labels = ["Type 2"], axis=1, inplace = True)

# %%
data_pokeman.head()
# Out:
#    SI no                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass    318  45      49       49       65
# 1      2                Ivysaur  Grass    405  60      62       63       80
# 2      3               Venusaur  Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4      4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
data_pokeman.drop(labels = ['Name', 'Type 1', 'Generation', 'Legendary'], axis=1, inplace = True)

# %%
data_pokeman.head()
# Out:
#    SI no  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      1    318  45      49       49       65       65     45
# 1      2    405  60      62       63       80       80     60
# 2      3    525  80      82       83      100      100     80
# 3      3    625  80     100      123      122      120     80
# 4      4    309  39      52       43       60       50     65

# %%
from sklearn.model_selection import train_test_split, cross_val_score
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:214, in __getattr__(name)
#     213 try:
# --> 214     return globals()[name]
#     215 except KeyError:
#
# KeyError: '_lib'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 from sklearn.model_selection import train_test_split, cross_val_score
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
# ...

# %%
X = data_pokeman.drop(columns=['SI no'], axis=1)
y = data_pokeman['Total']

# %%
print(X[:5])
print(X.shape)
print(y[:5])
print(y.shape)
# Out:
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    318  45      49       49       65       65     45
# 1    405  60      62       63       80       80     60
# 2    525  80      82       83      100      100     80
# 3    625  80     100      123      122      120     80
# 4    309  39      52       43       60       50     65
# (800, 7)
# 0    318
# 1    405
# 2    525
# 3    625
# 4    309
# Name: Total, dtype: int64
# (800,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (600, 7)
# (200, 7)
# (600,)
# (200,)

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# classify column

def classify(model):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print('Accuracy:', model.score(x_test, y_test))
    
    score = cross_val_score(model, X, y, cv=5)
    print('CV Score:', np.mean(score))

# %%
# ML model - ' LogisticRegression '

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Accuracy: 0.045
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
# ML model - ' DecisionTreeClassifier '

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model)
# Out:
# Accuracy: 0.775
# CV Score: 0.78
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
# ML model - ' RandomForestClassifier '

from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model)
# Out:
# Accuracy: 0.38
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CV Score: 0.42374999999999996

# %%
# ML model - ' ExtraTreesClassifier '

from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
classify(model)
# Out:
# Accuracy: 0.33
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CV Score: 0.38625

# %%
# ML model - ' XGBClassifier '

from xgboost import XGBClassifier
model = XGBClassifier()
classify(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [91], line 5
#       3 from xgboost import XGBClassifier
#       4 model = XGBClassifier()
# ----> 5 classify(model)
#
# Cell In [86], line 7, in classify(model)
#       5 def classify(model):
#       6     x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# ----> 7     model.fit(x_train, y_train)
#       8     print('Accuracy:', model.score(x_test, y_test))
#      10     score = cross_val_score(model, X, y, cv=5)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:575, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     573 for k, arg in zip(sig.parameters, args):
#     574     kwargs[k] = arg
# --> 575 return f(**kwargs)
#
# ...

# %%
# ML model - ' LGBMClassifier '

from lightgbm import LGBMClassifier
model = LGBMClassifier()
classify(model)
# Out:
# Accuracy: 0.7
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CV Score: 0.76

# %%
from sklearn.svm import SVC
model = SVC()
classify(model)
# Out:
# Accuracy: 0.12
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# CV Score: 0.14750000000000002

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
classify(model)
# Out:
# Accuracy: 0.18
# CV Score: 0.19875
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:684: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
